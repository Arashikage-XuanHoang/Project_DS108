# %%
import pandas as pd
import numpy as np
from unidecode import unidecode

# %%
# Danh sách các phần tiền tố (không bao gồm phần 'Bundesliga')
file_parts = [
    "base_info",
    "data_details_Aerial",
    "data_details_Assists",
    "data_details_Blocks",
    "data_details_Cards",
    "data_details_Clearances",
    "data_details_Dribbles",
    "data_details_Fouls",
    "data_details_Goals",
    "data_details_Interception",
    "data_details_Key passes",
    "data_details_Offsides",
    "data_details_Passes",
    "data_details_Possession loss",
    "data_details_Saves",
    "data_details_Shots",
    "data_details_Tackles",
    "data_summary"
]

# Tạo danh sách file dành cho EPL
filenames = [f"{part}_Ligue1.csv" for part in file_parts]

# Đọc các file CSV
df_list = [pd.read_csv(file) for file in filenames]

# Ghép lại theo chiều ngang
data = pd.concat(df_list, axis=1)

# Hiển thị kết quả
data.head()
# Out:
#    Unnamed: 0                 Name                 Club  \
# 0           0  Benjamin Bourigeaud               Rennes
# 1           1          Logan Costa           Villarreal
# 2           2      Ousmane Dembélé  Paris Saint-Germain
# 3           3        Ismail Jakobs          Galatasaray
# 4           4         Amine Gouiri            Marseille
#
#                          Age Height National  \
# 0  31 years old (14-01-1994)  178cm   France
# 1  24 years old (01-04-2001)  190cm   France
# 2  27 years old (15-05-1997)  178cm   France
# 3  25 years old (17-08-1999)  184cm  Senegal
# 4  25 years old (16-02-2000)  180cm   France
#
#                                            Positions  Unnamed: 0 TotAD WonAD  \
# 0                   Midfielder (Centre, Left, Right)           0     4     2
# 1                                  Defender (Centre)           1     6     4
# 2  Attacking Midfielder (Centre, Left, Right), Fo...           2   0.3   0.1
# 3                 Defender (Left), Midfielder (Left)           3   3.5   0.5
# 4  Attacking Midfielder (Centre, Left, Right), Fo...           4   1.1   0.2
#
#    ...  Mins  Goals Assists Yel Red  SpG   PS% AerialsWon MotM  Rating
# 0  ...    81      1       -   -   -    2  85.7          2    -    7.99
# 1  ...    90      -       -   -   -    -  83.3          4    -    7.73
# 2  ...  1663     21       6   2   -  3.3  83.3        0.1    9    7.70
# 3  ...   180      -       -   -   -    -  88.5        0.5    -    7.55
# 4  ...   789      7       3   -   -  3.9  89.7        0.2    2    7.44
#
# [5 rows x 84 columns]

# %%
data= data.drop(columns= ['Unnamed: 0', 'Name'])
data['League'] = 'Ligue1'

# %%
count_club = data['Club'].value_counts()
count_club
# Out:
# Club
# Rennes                 32
# Montpellier            32
# Marseille              29
# Reims                  29
# Nice                   29
#                        ..
# Pisa                    1
# Hull                    1
# Laval                   1
# Deportivo La Coruna     1
# Pau                     1
# Name: count, Length: 73, dtype: int64

# %%
data = data[data['Club'].isin(count_club[count_club > 20].index)]

# %%
count_club = data['Club'].value_counts()
count_club
# Out:
# Club
# Rennes                 32
# Montpellier            32
# Marseille              29
# Nice                   29
# Reims                  29
# Lens                   28
# Saint-Etienne          28
# Nantes                 28
# Auxerre                27
# Brest                  27
# Monaco                 26
# Angers                 26
# Le Havre               26
# Lille                  24
# Toulouse               24
# Lyon                   22
# Strasbourg             22
# Paris Saint-Germain    22
# Name: count, dtype: int64

# %%
invalid_player = data[data.duplicated(subset='Player', keep=False)]


for p in invalid_player['Player'].unique():
    
    players = data[data['Player'] == p]
    
    # Tìm phần tử có số phút thi đấu Mins lớn nhất
    player_to_keep = players.loc[players['Mins'].idxmax()]
    
    # Xóa các phần tử còn lại
    data = data.drop(players[players.index != player_to_keep.name].index)

# %%
data_info = data.sort_values(by = 'Player', ascending= True)
data_value = pd.read_csv('D:\Python_Code\Project_DS108\ds108\Transfermark \Ligue1\Ligue1_Value.csv')

# %%
#data_value['Name'] = data_value['Name'].apply(unidecode)
#data_info['Player'] = data_info['Player'].apply(unidecode)
# Bỏ dấu, chuyển chữ thường và loại dấu gạch nối
data_value['Name'] = data_value['Name'].apply(lambda x: unidecode(x).lower().replace("-", " "))
# Bỏ dấu, chuyển chữ thường và thay dấu gạch nối bằng dấu cách
data_info['Player'] = data_info['Player'].apply(lambda x: unidecode(x).lower().replace("-", " "))

# %%
merged_rows = []
name_not_found = []
not_found_indices = []

for i in range(len(data_info)):
    flag = 0
    for j in range(len(data_value)):
        if data_info.iloc[i]['Player'] == data_value.iloc[j]['Name']:
            # Nối 2 hàng lại theo chiều ngang
            merged = pd.concat([
                data_info.iloc[i],
                data_value.iloc[j].drop('Name')  # bỏ cột trùng
            ])
            merged_rows.append(merged)

            flag = 1
            break
    if flag == 0:
        print('Index = ', i, 'Not Found : ', data_info.iloc[i]['Player'])
        name_not_found.append(data_info.iloc[i]['Player'])
        not_found_indices.append(i)
# Out:
# Index =  7 Not Found :  abner vinicius
# Index =  14 Not Found :  al musrati
# Index =  18 Not Found :  alexi koum
# Index =  19 Not Found :  alexsandro ribeiro
# Index =  28 Not Found :  amine salama
# Index =  35 Not Found :  andres gomez
# Index =  38 Not Found :  ange tia
# Index =  55 Not Found :  axel gueguin
# Index =  68 Not Found :  ben viadere
# Index =  71 Not Found :  benjamin bourigeaud
# Index =  73 Not Found :  beraldo
# Index =  74 Not Found :  bernard nguene
# Index =  76 Not Found :  birama toure
# Index =  90 Not Found :  cristian casseres
# Index =  113 Not Found :  edhy zuliani
# Index =  121 Not Found :  enzo sternal
# Index =  145 Not Found :  gabin capuano
# Index =  167 Not Found :  hafiz ibrahim
# Index =  168 Not Found :  hamed traore
# Index =  180 Not Found :  hakon haraldsson
# Index =  187 Not Found :  ikechukwu orazi
# Index =  195 Not Found :  issiaga camara
# Index =  203 Not Found :  jibril othman
# Index =  216 Not Found :  jordan siebatcheu
# Index =  228 Not Found :  junior ndiaye
# Index =  231 Not Found :  justin noel kalumba
# Index =  240 Not Found :  kembo diliwidi
# Index =  242 Not Found :  keyliane abdallah
# Index =  248 Not Found :  koka
# Index =  250 Not Found :  kyllian antonio
# Index =  253 Not Found :  kevin pedro
# Index =  258 Not Found :  lee kang in
# Index =  266 Not Found :  lois diony
# Index =  288 Not Found :  mamadou coulibaly
# Index =  294 Not Found :  marius courcoul
# Index =  298 Not Found :  marwann n'zuzi
# Index =  304 Not Found :  matheo bodmer
# Index =  319 Not Found :  mohamed meite
# Index =  326 Not Found :  mousa al ta'mari
# Index =  338 Not Found :  niama sissoko
# Index =  363 Not Found :  plamedi nsingi
# Index =  366 Not Found :  prosper peter
# Index =  374 Not Found :  rayan fofana
# Index =  376 Not Found :  robinio vaz
# Index =  380 Not Found :  rudy matondo
# Index =  384 Not Found :  saliou diop
# Index =  385 Not Found :  sam amo ameyaw
# Index =  387 Not Found :  said benrahma
# Index =  389 Not Found :  saimon bouabre
# Index =  396 Not Found :  simon cara
# Index =  402 Not Found :  stefan dzodic
# Index =  404 Not Found :  sekou doucoure
# Index =  417 Not Found :  theo chennahi
# Index =  427 Not Found :  valentin atangana edoa
# Index =  430 Not Found :  valentin carboni
# Index =  440 Not Found :  wilfried ndollo bille
# Index =  443 Not Found :  yael mouanga
# Index =  445 Not Found :  yanis issoufou
# Index =  453 Not Found :  yoann cisse
# Index =  455 Not Found :  younes lachaab
# Index =  460 Not Found :  zabi gueu
# Index =  465 Not Found :  alex dominguez
# Index =  467 Not Found :  etienne youte

# %%
for idx, name in zip(not_found_indices, name_not_found):
    last_name_1 = name.split(' ')[-1]
    found = False
    for j in range(len(data_value)):
        last_name_2 = data_value.iloc[j]['Name'].split(' ')[-1]
        if last_name_1 == last_name_2:
            merged = pd.concat([
                data_info.iloc[idx],
                data_value.iloc[j].drop('Name')  # bỏ cột trùng
            ])
            merged_rows.append(merged)
            found = True
            break
    if not found:
        print('Still not found:', name)
# Out:
# Still not found: abner vinicius
# Still not found: alexi koum
# Still not found: alexsandro ribeiro
# Still not found: amine salama
# Still not found: ange tia
# Still not found: axel gueguin
# Still not found: ben viadere
# Still not found: benjamin bourigeaud
# Still not found: bernard nguene
# Still not found: cristian casseres
# Still not found: edhy zuliani
# Still not found: enzo sternal
# Still not found: gabin capuano
# Still not found: hafiz ibrahim
# Still not found: ikechukwu orazi
# Still not found: jibril othman
# Still not found: jordan siebatcheu
# Still not found: kembo diliwidi
# Still not found: keyliane abdallah
# Still not found: koka
# Still not found: kyllian antonio
# Still not found: kevin pedro
# Still not found: lee kang in
# Still not found: lois diony
# Still not found: marius courcoul
# Still not found: marwann n'zuzi
# Still not found: matheo bodmer
# Still not found: mousa al ta'mari
# Still not found: plamedi nsingi
# Still not found: prosper peter
# Still not found: robinio vaz
# Still not found: rudy matondo
# Still not found: said benrahma
# Still not found: saimon bouabre
# Still not found: simon cara
# Still not found: stefan dzodic
# Still not found: sekou doucoure
# Still not found: theo chennahi
# Still not found: valentin atangana edoa
# Still not found: valentin carboni
# Still not found: wilfried ndollo bille
# Still not found: yael mouanga
# Still not found: yanis issoufou
# Still not found: younes lachaab
# Still not found: zabi gueu
# Still not found: alex dominguez
# Still not found: etienne youte

# %%
for i in range(len(merged_rows)):
    merged_rows[i] = merged_rows[i].to_dict()
data = pd.DataFrame(merged_rows)

data['Player'] = data['Player'].str.title()
data.to_csv('Final_Ligue1.csv')

# %%
data['Player']
# Out:
# 0         Abakar Sylla
# 1        Abdallah Sima
# 2          Abdoul Kone
# 3      Abdoul Ouattara
# 4      Abdoulaye Bamba
#             ...
# 418      Niama Sissoko
# 419       Rayan Fofana
# 420        Saliou Diop
# 421     Sam Amo Ameyaw
# 422        Yoann Cisse
# Name: Player, Length: 423, dtype: object
