# %%
pip install unidecode
# Out:
# Requirement already satisfied: unidecode in c:\users\admin\anaconda3\envs\my_env\lib\site-packages (1.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from unidecode import unidecode

# %%
# Danh sách các phần tiền tố (không bao gồm phần 'Bundesliga')
file_parts = [
    "base_info",
    "data_details_Aerial",
    "data_details_Assists",
    "data_details_Blocks",
    "data_details_Cards",
    "data_details_Clearances",
    "data_details_Dribbles",
    "data_details_Fouls",
    "data_details_Goals",
    "data_details_Interception",
    "data_details_Key passes",
    "data_details_Offsides",
    "data_details_Passes",
    "data_details_Possession loss",
    "data_details_Saves",
    "data_details_Shots",
    "data_details_Tackles",
    "data_summary"
]

# Tạo danh sách file dành cho EPL
filenames = [f"{part}_Laliga.csv" for part in file_parts]

# Đọc các file CSV
df_list = [pd.read_csv(file) for file in filenames]

# Ghép lại theo chiều ngang
data = pd.concat(df_list, axis=1)

# Hiển thị kết quả
data.head()
# Out:
#    Unnamed: 0             Name         Club                        Age Height  \
# 0           0     Lamine Yamal    Barcelona  17 years old (13-07-2007)  180cm
# 1           1   Sergio Arribas   Real Betis  22 years old (10-02-2003)  185cm
# 2           2  Aitor Fernández      Osasuna  33 years old (03-05-1991)  182cm
# 3           3         Raphinha    Barcelona  28 years old (14-12-1996)  176cm
# 4           4    Kylian Mbappé  Real Madrid  26 years old (20-12-1998)  178cm
#
#   National                                          Positions  Unnamed: 0  \
# 0    Spain                       Attacking Midfielder (Right)           0
# 1    Spain                                           Defender           1
# 2    Spain                                         Goalkeeper           2
# 3   Brazil  Attacking Midfielder (Centre, Left, Right), Fo...           3
# 4   France  Attacking Midfielder (Centre, Left, Right), Fo...           4
#
#   TotAD WonAD  ...  Mins  Goals Assists Yel Red  SpG   PS% AerialsWon MotM  \
# 0   0.1     -  ...  2452      6      12   3   -  3.8  78.3          -    9
# 1     1     1  ...    90      -       -   -   -    -  68.3          1    -
# 2     -     -  ...    90      -       -   -   -    -    61          -    -
# 3   0.4   0.3  ...  2466     15       9   4   -  3.1  78.6        0.3   10
# 4   0.3   0.1  ...  2467     22       3   3   1  4.4    85        0.1    7
#
#    Rating
# 0    7.94
# 1    7.78
# 2    7.77
# 3    7.70
# 4    7.65
#
# [5 rows x 84 columns]

# %%
data= data.drop(columns= ['Unnamed: 0', 'Name'])
data['League'] = 'Laliga'

# %%
count_club = data['Club'].value_counts()
count_club
# Out:
# Club
# Real Valladolid    31
# Sevilla            31
# Valencia           31
# Getafe             30
# Real Betis         30
#                    ..
# Strasbourg          1
# PFC Sochi           1
# Boca Juniors        1
# Saint-Etienne       1
# San Diego FC        1
# Name: count, Length: 61, dtype: int64

# %%
data = data[data['Club'].isin(count_club[count_club > 20].index)]

# %%
player_count = data['Player'].value_counts()
player_count
# Out:
# Player
# Juan Cruz             2
# Carles Aleñá          2
# Joseph Aidoo          2
# Arnaut Danjuma        2
# Umar Sadiq            2
#                      ..
# David Soria           1
# Yuri Berchiche        1
# Carlos Romero         1
# Joan Jordán           1
# Valentín Pezzolesi    1
# Name: count, Length: 530, dtype: int64

# %%
invalid_player = data[data.duplicated(subset='Player', keep=False)]


for p in invalid_player['Player'].unique():
    
    players = data[data['Player'] == p]
    
    # Tìm phần tử có số phút thi đấu Mins lớn nhất
    player_to_keep = players.loc[players['Mins'].idxmax()]
    
    # Xóa các phần tử còn lại
    data = data.drop(players[players.index != player_to_keep.name].index)

# %%
data_info = data.sort_values(by = 'Player', ascending= True)
data_value = pd.read_csv('D:\Python_Code\Project_DS108\ds108\Transfermark \Laliga\Laliga_Value.csv')

# %%
#data_value['Name'] = data_value['Name'].apply(unidecode)
#data_info['Player'] = data_info['Player'].apply(unidecode)
# Bỏ dấu, chuyển chữ thường và loại dấu gạch nối
data_value['Name'] = data_value['Name'].apply(lambda x: unidecode(x).lower().replace("-", " "))
# Bỏ dấu, chuyển chữ thường và thay dấu gạch nối bằng dấu cách
data_info['Player'] = data_info['Player'].apply(lambda x: unidecode(x).lower().replace("-", " "))

# %%
merged_rows = []
name_not_found = []
not_found_indices = []

for i in range(len(data_info)):
    flag = 0
    for j in range(len(data_value)):
        if data_info.iloc[i]['Player'] == data_value.iloc[j]['Name']:
            # Nối 2 hàng lại theo chiều ngang
            merged = pd.concat([
                data_info.iloc[i],
                data_value.iloc[j].drop('Name')  # bỏ cột trùng
            ])
            merged_rows.append(merged)

            flag = 1
            break
    if flag == 0:
        print('Index = ', i, 'Not Found : ', data_info.iloc[i]['Player'])
        name_not_found.append(data_info.iloc[i]['Player'])
        not_found_indices.append(i)
# Out:
# Index =  2 Not Found :  abdoulaye keita
# Index =  7 Not Found :  aboubacar bassinga
# Index =  11 Not Found :  adri embarba
# Index =  12 Not Found :  adria alti
# Index =  15 Not Found :  adrian arnu
# Index =  16 Not Found :  adrian nino
# Index =  19 Not Found :  adu ares
# Index =  47 Not Found :  andrii lunin
# Index =  62 Not Found :  anuar tuhami
# Index =  68 Not Found :  arnau rafus
# Index =  69 Not Found :  arnau sola
# Index =  72 Not Found :  arthur
# Index =  94 Not Found :  carlos benavidez
# Index =  96 Not Found :  carlos guirao
# Index =  101 Not Found :  chema andres
# Index =  110 Not Found :  copete
# Index =  120 Not Found :  dani carvajal
# Index =  123 Not Found :  dani gomez
# Index =  129 Not Found :  daniel diaz
# Index =  130 Not Found :  daniel yanez
# Index =  133 Not Found :  dario benavides
# Index =  135 Not Found :  david arguelles
# Index =  137 Not Found :  david otorbi
# Index =  143 Not Found :  diego hormigo
# Index =  149 Not Found :  djene dakonam
# Index =  159 Not Found :  endika bujan
# Index =  168 Not Found :  etienne eto'o pineda
# Index =  169 Not Found :  etta eyong
# Index =  175 Not Found :  fernando lopez
# Index =  177 Not Found :  ferran ruiz
# Index =  189 Not Found :  garcia pascual
# Index =  198 Not Found :  gorka rivera
# Index =  200 Not Found :  henrique
# Index =  210 Not Found :  iker cordoba
# Index =  218 Not Found :  ismael bekhoucha
# Index =  219 Not Found :  israel dominguez
# Index =  231 Not Found :  jan salas
# Index =  243 Not Found :  jesus navas
# Index =  258 Not Found :  jon olasagasti
# Index =  264 Not Found :  jose arnaiz
# Index =  275 Not Found :  juan herzog
# Index =  295 Not Found :  kim min su
# Index =  301 Not Found :  leandro antonetti
# Index =  305 Not Found :  lorenzo aguado
# Index =  316 Not Found :  luken beitia
# Index =  327 Not Found :  marc domenech
# Index =  334 Not Found :  mario maroto
# Index =  343 Not Found :  mateo mejia
# Index =  359 Not Found :  nabil fekir
# Index =  368 Not Found :  oliver mcburnie
# Index =  377 Not Found :  pablo garcia
# Index =  382 Not Found :  papa dame ba
# Index =  393 Not Found :  pejino
# Index =  403 Not Found :  rafael bauza
# Index =  405 Not Found :  ramon martinez
# Index =  410 Not Found :  raul chasco
# Index =  414 Not Found :  reinildo
# Index =  422 Not Found :  rodri
# Index =  423 Not Found :  rodrigo abajas
# Index =  427 Not Found :  roger hinojo
# Index =  445 Not Found :  sergi dominguez
# Index =  448 Not Found :  sergio arribas
# Index =  459 Not Found :  stoichkov
# Index =  467 Not Found :  thiago ojeda
# Index =  482 Not Found :  urko gonzalez
# Index =  484 Not Found :  valentin pezzolesi
# Index =  496 Not Found :  yan diomande

# %%
for idx, name in zip(not_found_indices, name_not_found):
    last_name_1 = name.split(' ')[-1]
    found = False
    for j in range(len(data_value)):
        last_name_2 = data_value.iloc[j]['Name'].split(' ')[-1]
        if last_name_1 == last_name_2:
            merged = pd.concat([
                data_info.iloc[idx],
                data_value.iloc[j].drop('Name')  # bỏ cột trùng
            ])
            merged_rows.append(merged)
            found = True
            break
    if not found:
        print('Still not found:', name)
# Out:
# Still not found: abdoulaye keita
# Still not found: aboubacar bassinga
# Still not found: adria alti
# Still not found: adrian arnu
# Still not found: adrian nino
# Still not found: adu ares
# Still not found: anuar tuhami
# Still not found: arnau rafus
# Still not found: arthur
# Still not found: carlos benavidez
# Still not found: carlos guirao
# Still not found: chema andres
# Still not found: daniel yanez
# Still not found: dario benavides
# Still not found: david arguelles
# Still not found: david otorbi
# Still not found: diego hormigo
# Still not found: djene dakonam
# Still not found: endika bujan
# Still not found: etienne eto'o pineda
# Still not found: etta eyong
# Still not found: garcia pascual
# Still not found: gorka rivera
# Still not found: henrique
# Still not found: iker cordoba
# Still not found: ismael bekhoucha
# Still not found: jesus navas
# Still not found: kim min su
# Still not found: leandro antonetti
# Still not found: luken beitia
# Still not found: mario maroto
# Still not found: mateo mejia
# Still not found: nabil fekir
# Still not found: papa dame ba
# Still not found: pejino
# Still not found: raul chasco
# Still not found: reinildo
# Still not found: rodri
# Still not found: rodrigo abajas
# Still not found: roger hinojo
# Still not found: sergio arribas
# Still not found: stoichkov
# Still not found: thiago ojeda
# Still not found: valentin pezzolesi
# Still not found: yan diomande

# %%
for i in range(len(merged_rows)):
    merged_rows[i] = merged_rows[i].to_dict()
data = pd.DataFrame(merged_rows)

data['Player'] = data['Player'].str.title()
data.to_csv('Final_Laliga.csv')
