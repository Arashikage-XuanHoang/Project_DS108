# %%
import pandas as pd
import numpy as np

# %%
data_serieA = pd.read_csv('D:\Python_Code\Project_DS108\ds108\WhoScore\Serie A\Final_SerieA.csv')
data_serieA.columns
# Out:
# Index(['Unnamed: 0.1', 'Club', 'Age', 'Height', 'National', 'Positions',
#        'TotAD', 'WonAD', 'LostAD', 'CrAss', 'CorAss', 'ThrbAss', 'FreAss',
#        'ThrInAss', 'OthAss', 'TotAss', 'BlkSh', 'BlkCr', 'BlkPs', 'YelC',
#        'RedC', 'TotClr', 'UnDrib', 'SucDrib', 'TotDrib', 'Fouled', 'Fouls',
#        'TotGs', 'Unnamed: 2', 'SYBGs', 'PAGs', 'OOBGs', 'TotInt', 'TotKPs',
#        'LKPs', 'SKPs', 'COF', 'TotPs', 'AccLB', 'InAccLB', 'AccSP', 'InAccSP',
#        'UnTch', 'Dispo', 'TotSav', 'SYBSav', 'PASav', 'OOBSav', 'TotSh',
#        'OOBSh', 'SYBSh', 'PASh', 'TotTkl', 'DribPast', 'TotAttTkl', 'Player',
#        'Apps', 'Mins', 'Goals', 'Assists', 'Yel', 'Red', 'SpG', 'PS%',
#        'AerialsWon', 'MotM', 'Rating', 'League', 'Unnamed: 0', 'CLB',
#        'Main_position', 'Foot', 'Contract', 'Market_Value'],
#       dtype='object')

# %%
to_drop = ['Unnamed: 0.1', 'Unnamed: 0']
data_serieA = data_serieA.drop(columns= to_drop)
data_serieA = data_serieA.drop(columns= 'Unnamed: 2')

data_serieA.columns
# Out:
# Index(['Club', 'Age', 'Height', 'National', 'Positions', 'TotAD', 'WonAD',
#        'LostAD', 'CrAss', 'CorAss', 'ThrbAss', 'FreAss', 'ThrInAss', 'OthAss',
#        'TotAss', 'BlkSh', 'BlkCr', 'BlkPs', 'YelC', 'RedC', 'TotClr', 'UnDrib',
#        'SucDrib', 'TotDrib', 'Fouled', 'Fouls', 'TotGs', 'SYBGs', 'PAGs',
#        'OOBGs', 'TotInt', 'TotKPs', 'LKPs', 'SKPs', 'COF', 'TotPs', 'AccLB',
#        'InAccLB', 'AccSP', 'InAccSP', 'UnTch', 'Dispo', 'TotSav', 'SYBSav',
#        'PASav', 'OOBSav', 'TotSh', 'OOBSh', 'SYBSh', 'PASh', 'TotTkl',
#        'DribPast', 'TotAttTkl', 'Player', 'Apps', 'Mins', 'Goals', 'Assists',
#        'Yel', 'Red', 'SpG', 'PS%', 'AerialsWon', 'MotM', 'Rating', 'League',
#        'CLB', 'Main_position', 'Foot', 'Contract', 'Market_Value'],
#       dtype='object')

# %%
data_ligue1 = pd.read_csv('D:\Python_Code\Project_DS108\ds108\WhoScore\Ligue1\Final_Ligue1.csv')
data_ligue1 = data_ligue1.drop(columns= to_drop)
data_ligue1.columns
# Out:
# Index(['Club', 'Age', 'Height', 'National', 'Positions', 'TotAD', 'WonAD',
#        'LostAD', 'CrAss', 'CorAss', 'ThrbAss', 'FreAss', 'ThrInAss', 'OthAss',
#        'TotAss', 'BlkSh', 'BlkCr', 'BlkPs', 'YelC', 'RedC', 'TotClr', 'UnDrib',
#        'SucDrib', 'TotDrib', 'Fouled', 'Fouls', 'TotGs', 'SYBGs', 'PAGs',
#        'OOBGs', 'TotInt', 'TotKPs', 'LKPs', 'SKPs', 'COF', 'TotPs', 'AccLB',
#        'InAccLB', 'AccSP', 'InAccSP', 'UnTch', 'Dispo', 'TotSav', 'SYBSav',
#        'PASav', 'OOBSav', 'TotSh', 'OOBSh', 'SYBSh', 'PASh', 'TotTkl',
#        'DribPast', 'TotAttTkl', 'Player', 'Apps', 'Mins', 'Goals', 'Assists',
#        'Yel', 'Red', 'SpG', 'PS%', 'AerialsWon', 'MotM', 'Rating', 'League',
#        'CLB', 'Main_position', 'Foot', 'Contract', 'Market_Value'],
#       dtype='object')

# %%
data_bundesliga = pd.read_csv('D:\Python_Code\Project_DS108\ds108\WhoScore\Bundesliga\Final_Bundesliga.csv')
to_drop_1 = ['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0']
data_bundesliga = data_bundesliga.drop(columns= to_drop_1)
data_bundesliga.columns
# Out:
# Index(['Club', 'Age', 'Height', 'National', 'Positions', 'TotAD', 'WonAD',
#        'LostAD', 'CrAss', 'CorAss', 'ThrbAss', 'FreAss', 'ThrInAss', 'OthAss',
#        'TotAss', 'BlkSh', 'BlkCr', 'BlkPs', 'YelC', 'RedC', 'TotClr', 'UnDrib',
#        'SucDrib', 'TotDrib', 'Fouled', 'Fouls', 'TotGs', 'SYBGs', 'PAGs',
#        'OOBGs', 'TotInt', 'TotKPs', 'LKPs', 'SKPs', 'COF', 'TotPs', 'AccLB',
#        'InAccLB', 'AccSP', 'InAccSP', 'UnTch', 'Dispo', 'TotSav', 'SYBSav',
#        'PASav', 'OOBSav', 'TotSh', 'OOBSh', 'SYBSh', 'PASh', 'TotTkl',
#        'DribPast', 'TotAttTkl', 'Player', 'Apps', 'Mins', 'Goals', 'Assists',
#        'Yel', 'Red', 'SpG', 'PS%', 'AerialsWon', 'MotM', 'Rating', 'League',
#        'CLB', 'Main_position', 'Foot', 'Contract', 'Market_Value'],
#       dtype='object')

# %% [markdown]
# ** Bundesliga : Đổi ToTAD -> TotAD

# %%
data_laliga = pd.read_csv('D:\Python_Code\Project_DS108\ds108\WhoScore\Laliga\Final_Laliga.csv')
data_laliga= data_laliga.drop(columns= to_drop)
data_laliga.columns
# Out:
# Index(['Club', 'Age', 'Height', 'National', 'Positions', 'TotAD', 'WonAD',
#        'LostAD', 'CrAss', 'CorAss', 'ThrbAss', 'FreAss', 'ThrInAss', 'OthAss',
#        'TotAss', 'BlkSh', 'BlkCr', 'BlkPs', 'YelC', 'RedC', 'TotClr', 'UnDrib',
#        'SucDrib', 'TotDrib', 'Fouled', 'Fouls', 'TotGs', 'SYBGs', 'PAGs',
#        'OOBGs', 'TotInt', 'TotKPs', 'LKPs', 'SKPs', 'COF', 'TotPs', 'AccLB',
#        'InAccLB', 'AccSP', 'InAccSP', 'UnTch', 'Dispo', 'TotSav', 'SYBSav',
#        'PASav', 'OOBSav', 'TotSh', 'OOBSh', 'SYBSh', 'PASh', 'TotTkl',
#        'DribPast', 'TotAttTkl', 'Player', 'Apps', 'Mins', 'Goals', 'Assists',
#        'Yel', 'Red', 'SpG', 'PS%', 'AerialsWon', 'MotM', 'Rating', 'League',
#        'CLB', 'Main_position', 'Foot', 'Contract', 'Market_Value'],
#       dtype='object')

# %% [markdown]
# ** Laliga có vấn đề

# %%
data_epl = pd.read_csv('D:\Python_Code\Project_DS108\ds108\WhoScore\EPL\Final_EPL.csv')
data_epl = data_epl.drop(columns= to_drop)
data_epl.columns
# Out:
# Index(['Club', 'Age', 'Height', 'National', 'Positions', 'TotAD', 'WonAD',
#        'LostAD', 'CrAss', 'CorAss', 'ThrbAss', 'FreAss', 'ThrInAss', 'OthAss',
#        'TotAss', 'BlkSh', 'BlkCr', 'BlkPs', 'YelC', 'RedC', 'TotClr', 'UnDrib',
#        'SucDrib', 'TotDrib', 'Fouled', 'Fouls', 'TotGs', 'SYBGs', 'PAGs',
#        'OOBGs', 'TotInt', 'TotKPs', 'LKPs', 'SKPs', 'COF', 'TotPs', 'AccLB',
#        'InAccLB', 'AccSP', 'InAccSP', 'UnTch', 'Dispo', 'TotSav', 'SYBSav',
#        'PASav', 'OOBSav', 'TotSh', 'OOBSh', 'SYBSh', 'PASh', 'TotTkl',
#        'DribPast', 'TotAttTkl', 'Player', 'Apps', 'Mins', 'Goals', 'Assists',
#        'Yel', 'Red', 'SpG', 'PS%', 'AerialsWon', 'MotM', 'Rating', 'League',
#        'CLB', 'Main_position', 'Foot', 'Contract', 'Market_Value'],
#       dtype='object')

# %% [markdown]
# ** Lấy EPL làm chuẩn
# - SerieA
# - Bundesliga
# - ligue1
# - laliga

# %%
for i in range(len(data_epl.columns)):
    if data_laliga.columns[i] != data_epl.columns[i]:
        print("Failed : ", data_laliga.columns[i], data_epl.columns[i])
        break
    else:
        print(data_laliga.columns[i], data_epl.columns[i])
# Out:
# Club Club
# Age Age
# Height Height
# National National
# Positions Positions
# TotAD TotAD
# WonAD WonAD
# LostAD LostAD
# CrAss CrAss
# CorAss CorAss
# ThrbAss ThrbAss
# FreAss FreAss
# ThrInAss ThrInAss
# OthAss OthAss
# TotAss TotAss
# BlkSh BlkSh
# BlkCr BlkCr
# BlkPs BlkPs
# YelC YelC
# RedC RedC
# TotClr TotClr
# UnDrib UnDrib
# SucDrib SucDrib
# TotDrib TotDrib
# Fouled Fouled
# Fouls Fouls
# TotGs TotGs
# SYBGs SYBGs
# PAGs PAGs
# OOBGs OOBGs
# TotInt TotInt
# TotKPs TotKPs
# LKPs LKPs
# SKPs SKPs
# COF COF
# TotPs TotPs
# AccLB AccLB
# InAccLB InAccLB
# AccSP AccSP
# InAccSP InAccSP
# UnTch UnTch
# Dispo Dispo
# TotSav TotSav
# SYBSav SYBSav
# PASav PASav
# OOBSav OOBSav
# TotSh TotSh
# OOBSh OOBSh
# SYBSh SYBSh
# PASh PASh
# TotTkl TotTkl
# DribPast DribPast
# TotAttTkl TotAttTkl
# Player Player
# Apps Apps
# Mins Mins
# Goals Goals
# Assists Assists
# Yel Yel
# Red Red
# SpG SpG
# PS% PS%
# AerialsWon AerialsWon
# MotM MotM
# Rating Rating
# League League
# CLB CLB
# ...

# %%
data_laliga.columns
# Out:
# Index(['Club', 'Age', 'Height', 'National', 'Positions', 'TotAD', 'WonAD',
#        'LostAD', 'CrAss', 'CorAss', 'ThrbAss', 'FreAss', 'ThrInAss', 'OthAss',
#        'TotAss', 'BlkSh', 'BlkCr', 'BlkPs', 'YelC', 'RedC', 'TotClr', 'UnDrib',
#        'SucDrib', 'TotDrib', 'Fouled', 'Fouls', 'TotGs', 'SYBGs', 'PAGs',
#        'OOBGs', 'TotInt', 'TotKPs', 'LKPs', 'SKPs', 'COF', 'TotPs', 'AccLB',
#        'InAccLB', 'AccSP', 'InAccSP', 'UnTch', 'Dispo', 'TotSav', 'SYBSav',
#        'PASav', 'OOBSav', 'TotSh', 'OOBSh', 'SYBSh', 'PASh', 'TotTkl',
#        'DribPast', 'TotAttTkl', 'Player', 'Apps', 'Mins', 'Goals', 'Assists',
#        'Yel', 'Red', 'SpG', 'PS%', 'AerialsWon', 'MotM', 'Rating', 'League',
#        'CLB', 'Main_position', 'Foot', 'Contract', 'Market_Value'],
#       dtype='object')

# %%
data_epl.columns
# Out:
# Index(['Club', 'Age', 'Height', 'National', 'Positions', 'TotAD', 'WonAD',
#        'LostAD', 'CrAss', 'CorAss', 'ThrbAss', 'FreAss', 'ThrInAss', 'OthAss',
#        'TotAss', 'BlkSh', 'BlkCr', 'BlkPs', 'YelC', 'RedC', 'TotClr', 'UnDrib',
#        'SucDrib', 'TotDrib', 'Fouled', 'Fouls', 'TotGs', 'SYBGs', 'PAGs',
#        'OOBGs', 'TotInt', 'TotKPs', 'LKPs', 'SKPs', 'COF', 'TotPs', 'AccLB',
#        'InAccLB', 'AccSP', 'InAccSP', 'UnTch', 'Dispo', 'TotSav', 'SYBSav',
#        'PASav', 'OOBSav', 'TotSh', 'OOBSh', 'SYBSh', 'PASh', 'TotTkl',
#        'DribPast', 'TotAttTkl', 'Player', 'Apps', 'Mins', 'Goals', 'Assists',
#        'Yel', 'Red', 'SpG', 'PS%', 'AerialsWon', 'MotM', 'Rating', 'League',
#        'CLB', 'Main_position', 'Foot', 'Contract', 'Market_Value'],
#       dtype='object')

# %%
data_serieA.columns
# Out:
# Index(['Club', 'Age', 'Height', 'National', 'Positions', 'TotAD', 'WonAD',
#        'LostAD', 'CrAss', 'CorAss', 'ThrbAss', 'FreAss', 'ThrInAss', 'OthAss',
#        'TotAss', 'BlkSh', 'BlkCr', 'BlkPs', 'YelC', 'RedC', 'TotClr', 'UnDrib',
#        'SucDrib', 'TotDrib', 'Fouled', 'Fouls', 'TotGs', 'SYBGs', 'PAGs',
#        'OOBGs', 'TotInt', 'TotKPs', 'LKPs', 'SKPs', 'COF', 'TotPs', 'AccLB',
#        'InAccLB', 'AccSP', 'InAccSP', 'UnTch', 'Dispo', 'TotSav', 'SYBSav',
#        'PASav', 'OOBSav', 'TotSh', 'OOBSh', 'SYBSh', 'PASh', 'TotTkl',
#        'DribPast', 'TotAttTkl', 'Player', 'Apps', 'Mins', 'Goals', 'Assists',
#        'Yel', 'Red', 'SpG', 'PS%', 'AerialsWon', 'MotM', 'Rating', 'League',
#        'CLB', 'Main_position', 'Foot', 'Contract', 'Market_Value'],
#       dtype='object')

# %%
data_bundesliga.columns
# Out:
# Index(['Club', 'Age', 'Height', 'National', 'Positions', 'TotAD', 'WonAD',
#        'LostAD', 'CrAss', 'CorAss', 'ThrbAss', 'FreAss', 'ThrInAss', 'OthAss',
#        'TotAss', 'BlkSh', 'BlkCr', 'BlkPs', 'YelC', 'RedC', 'TotClr', 'UnDrib',
#        'SucDrib', 'TotDrib', 'Fouled', 'Fouls', 'TotGs', 'SYBGs', 'PAGs',
#        'OOBGs', 'TotInt', 'TotKPs', 'LKPs', 'SKPs', 'COF', 'TotPs', 'AccLB',
#        'InAccLB', 'AccSP', 'InAccSP', 'UnTch', 'Dispo', 'TotSav', 'SYBSav',
#        'PASav', 'OOBSav', 'TotSh', 'OOBSh', 'SYBSh', 'PASh', 'TotTkl',
#        'DribPast', 'TotAttTkl', 'Player', 'Apps', 'Mins', 'Goals', 'Assists',
#        'Yel', 'Red', 'SpG', 'PS%', 'AerialsWon', 'MotM', 'Rating', 'League',
#        'CLB', 'Main_position', 'Foot', 'Contract', 'Market_Value'],
#       dtype='object')

# %%
data_ligue1.columns
# Out:
# Index(['Club', 'Age', 'Height', 'National', 'Positions', 'TotAD', 'WonAD',
#        'LostAD', 'CrAss', 'CorAss', 'ThrbAss', 'FreAss', 'ThrInAss', 'OthAss',
#        'TotAss', 'BlkSh', 'BlkCr', 'BlkPs', 'YelC', 'RedC', 'TotClr', 'UnDrib',
#        'SucDrib', 'TotDrib', 'Fouled', 'Fouls', 'TotGs', 'SYBGs', 'PAGs',
#        'OOBGs', 'TotInt', 'TotKPs', 'LKPs', 'SKPs', 'COF', 'TotPs', 'AccLB',
#        'InAccLB', 'AccSP', 'InAccSP', 'UnTch', 'Dispo', 'TotSav', 'SYBSav',
#        'PASav', 'OOBSav', 'TotSh', 'OOBSh', 'SYBSh', 'PASh', 'TotTkl',
#        'DribPast', 'TotAttTkl', 'Player', 'Apps', 'Mins', 'Goals', 'Assists',
#        'Yel', 'Red', 'SpG', 'PS%', 'AerialsWon', 'MotM', 'Rating', 'League',
#        'CLB', 'Main_position', 'Foot', 'Contract', 'Market_Value'],
#       dtype='object')
