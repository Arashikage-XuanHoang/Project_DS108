# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from fuzzywuzzy import process
import warnings

# %%
warnings.filterwarnings ('ignore')
pd.set_option ('display.width', None)
pd.set_option ('display.max_rows', 100)
pd.set_option ('display.max_columns', 50)

# %% [markdown]
# # Create `Football_Player_Profile` Dataset

# %% [markdown]
# ## Read *base_info_--.csv*

# %%
leagues = ['EPL','Laliga','Bundesliga','SerieA','Ligue1']
info = []
for league in leagues:
    path = f"ds108/{league}/base_info_{league}.csv"
    base_info_ = pd.read_csv (path)
    base_info_.insert (2, 'League',f'{league}')
    print (f"{league}: {base_info_.shape}")
    info.append (base_info_)
base_info = pd.concat (info, ignore_index=True)
# df = df.rename (columns={'ten_cu':'ten_moi'})
# Đổi cột Name --> Player để đồng nhất
base_info = base_info.rename (columns={'Name':'Player'})
base_info.drop (columns=['Unnamed: 0'], inplace=True)
base_info
# Out:
# EPL: (564, 7)
# Laliga: (587, 8)
# Bundesliga: (487, 8)
# SerieA: (625, 8)
# Ligue1: (543, 8)
#               Player             Club  League                        Age  \
# 0      Mohamed Salah        Liverpool     EPL  32 years old (15-06-1992)
# 1        Bukayo Saka          Arsenal     EPL  23 years old (05-09-2001)
# 2     Alexander Isak        Newcastle     EPL  25 years old (21-09-1999)
# 3      Matheus Cunha           Wolves     EPL  25 years old (27-05-1999)
# 4     Erling Haaland  Manchester City     EPL  24 years old (21-07-2000)
# ...              ...              ...     ...                        ...
# 2801  Bernard Nguene             Nice  Ligue1  18 years old (04-08-2006)
# 2802   Paul Akouokou             Lyon  Ligue1  27 years old (20-12-1997)
# 2803      Bamo Meïté      Montpellier  Ligue1  23 years old (03-12-2001)
# 2804    Élysée Logbo         Le Havre  Ligue1  20 years old (06-05-2004)
# 2805       Zabi Gueu            Reims  Ligue1  18 years old (24-09-2006)
#
#      Height     National                                          Positions
# 0     175cm        Egypt  Attacking Midfielder (Centre, Left, Right), Fo...
# 1     178cm      England  Defender (Left), Midfielder (Centre, Left, Right)
# 2     192cm       Sweden               Attacking Midfielder (Left), Forward
# 3     183cm       Brazil       Attacking Midfielder (Centre, Left), Forward
# 4     194cm       Norway                                            Forward
# ...     ...          ...                                                ...
# 2801  178cm     Cameroon                                            Forward
# 2802  181cm  Ivory Coast                           Defensive Midfielder (C)
# 2803  183cm          NaN                                  Defender (Centre)
# 2804  188cm       France                                            Forward
# 2805  191cm          NaN                                         Midfielder
#
# [2806 rows x 7 columns]

# %%
folder_path = 'ds108/Transfermarkt/EPL'
csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]
# Đọc từng file vào DataFrame
list_dfs = []
for file in csv_files:
    file_path = os.path.join(folder_path, file)  # nối đường dẫn đầy đủ
    df = pd.read_csv(file_path)
    list_dfs.append(df)

# Gộp lại
df_all = pd.concat(list_dfs, ignore_index=True)
df_all = df_all.rename (columns={'Name':'Player'})
names_df2 = df_all['Player'].tolist()

EPL = pd.read_csv ('ds108/EPL/base_info_EPL.csv')
EPL = EPL.rename (columns={'Name':'Player'})

EPL['Matched_Player'] = EPL['Player'].apply(lambda x: process.extractOne(x, names_df2)[0])
df_merged = pd.merge(EPL, df_all, left_on='Matched_Player', right_on='Player', how='outer')
df_merged
# df_merged = pd.merge(df_all, EPL, on='Player', how='outer')  # outer sẽ giữ tất cả dữ liệu từ cả 2 bảng
# Out:
#               Player_x               Club                        Age Height_x  \
# 0      Aaron Cresswell           West Ham  35 years old (15-12-1989)    170cm
# 1                  NaN                NaN                        NaN      NaN
# 2       Aaron Ramsdale        Southampton  26 years old (14-05-1998)    190cm
# 3    Aaron Wan-Bissaka           West Ham  27 years old (26-11-1997)    183cm
# 4                  NaN                NaN                        NaN      NaN
# ..                 ...                ...                        ...      ...
# 602  Yukinari Sugawara        Southampton  24 years old (28-06-2000)    179cm
# 603        Yunus Konak          Brentford  19 years old (10-01-2006)    181cm
# 604      Yves Bissouma          Tottenham  28 years old (30-08-1996)    182cm
# 605        Álex Moreno  Nottingham Forest  31 years old (08-06-1993)    179cm
# 606     Ilkay Gündogan    Manchester City  34 years old (24-10-1990)    180cm
#
#     National                                   Positions     Matched_Player  \
# 0    England  Defender (Centre, Left), Midfielder (Left)    Aaron Cresswell
# 1        NaN                                         NaN                NaN
# 2    England                                  Goalkeeper     Aaron Ramsdale
# 3    England  Defender (Left, Right), Midfielder (Right)  Aaron Wan-Bissaka
# 4        NaN                                         NaN                NaN
# ..       ...                                         ...                ...
# 602    Japan        Defender (Right), Midfielder (Right)  Yukinari Sugawara
# 603      NaN                    Defensive Midfielder (C)   Yunus Emre Konak
# 604     Mali                         Midfielder (Centre)      Yves Bissouma
# 605    Spain          Defender (Left), Midfielder (Left)        Álex Moreno
# 606  Germany                         Midfielder (Centre)     İlkay Gündoğan
#
#      Unnamed: 0                CLB           Player_y       Main_position  \
# 0             9    West Ham United    Aaron Cresswell           Left-Back
# 1             9       Brentford FC       Aaron Hickey          Right-Back
# 2             0     Southampton FC     Aaron Ramsdale          Goalkeeper
# 3            10    West Ham United  Aaron Wan-Bissaka          Right-Back
# 4             9         Chelsea FC    Aarón Anselmino         Centre-Back
# ..          ...                ...                ...                 ...
# 602          15     Southampton FC  Yukinari Sugawara          Right-Back
# 603          13       Brentford FC   Yunus Emre Konak  Defensive Midfield
# 604          16  Tottenham Hotspur      Yves Bissouma  Defensive Midfield
# 605           7  Nottingham Forest        Álex Moreno           Left-Back
# 606          15    Manchester City     İlkay Gündoğan    Central Midfield
#
#     Height_y   Foot      Contract Market_Value
# 0      1,70m   left  Jun 30, 2025        €700k
# 1      1,85m   both  Jun 30, 2028      €18.00m
# 2      1,90m  right  Jun 30, 2028      €16.00m
# 3      1,83m  right  Jun 30, 2031      €22.00m
# 4      1,86m  right  Jun 30, 2031       €8.00m
# ..       ...    ...           ...          ...
# 602    1,79m  right  Jun 30, 2028      €12.00m
# 603    1,81m  right  Jun 30, 2029       €4.50m
# 604    1,82m  right  Jun 30, 2026      €28.00m
# 605    1,79m   left  May 31, 2025      €11.00m
# 606    1,80m  right  Jun 30, 2026       €7.00m
#
# [607 rows x 15 columns]

# %%
df_concat = pd.concat([df_all, EPL], axis=1)
df_concat.to_csv ('text2.csv')

# %%
arsen_market = pd.read_csv ('ds108/Transfermarkt/EPL/Arsenal FC.csv')
arsen_market = arsen_market.rename (columns={'Name':'Player'})
arsenal = base_info.loc [base_info ['Club'] == 'Arsenal']
merged = pd.merge(arsenal, arsen_market, on="Player", how="left")  # Hoặc "inner"

merged
# Out:
#                  Player     Club League                        Age Height_x  \
# 0           Bukayo Saka  Arsenal    EPL  23 years old (05-09-2001)    178cm
# 1           Kai Havertz  Arsenal    EPL  25 years old (11-06-1999)    193cm
# 2           Declan Rice  Arsenal    EPL  26 years old (14-01-1999)    188cm
# 3                  Neto  Arsenal    EPL  35 years old (19-07-1989)    190cm
# 4         Thomas Partey  Arsenal    EPL  31 years old (13-06-1993)    185cm
# 5     Gabriel Magalhães  Arsenal    EPL  27 years old (19-12-1997)    190cm
# 6        William Saliba  Arsenal    EPL  24 years old (24-03-2001)    192cm
# 7       Martin Ødegaard  Arsenal    EPL  26 years old (17-12-1998)    178cm
# 8          Mikel Merino  Arsenal    EPL  28 years old (22-06-1996)    189cm
# 9    Gabriel Martinelli  Arsenal    EPL  23 years old (18-06-2001)    178cm
# 10           David Raya  Arsenal    EPL  29 years old (15-09-1995)    183cm
# 11     Leandro Trossard  Arsenal    EPL  30 years old (04-12-1994)    172cm
# 12       Jurriën Timber  Arsenal    EPL  23 years old (17-06-2001)    179cm
# 13   Riccardo Calafiori  Arsenal    EPL  22 years old (19-05-2002)    188cm
# 14        Ethan Nwaneri  Arsenal    EPL  18 years old (21-03-2007)    176cm
# 15        Gabriel Jesus  Arsenal    EPL  28 years old (03-04-1997)    175cm
# 16            Ben White  Arsenal    EPL  27 years old (08-10-1997)    186cm
# 17    Takehiro Tomiyasu  Arsenal    EPL  26 years old (05-11-1998)    187cm
# 18   Myles Lewis-Skelly  Arsenal    EPL  18 years old (26-09-2006)    178cm
# 19         Jakub Kiwior  Arsenal    EPL  25 years old (15-02-2000)    189cm
# 20       Kieran Tierney  Arsenal    EPL  27 years old (05-06-1997)    178cm
# 21      Raheem Sterling  Arsenal    EPL  30 years old (08-12-1994)    172cm
# 22  Oleksandr Zinchenko  Arsenal    EPL  28 years old (15-12-1996)    175cm
# 23             Jorginho  Arsenal    EPL  33 years old (20-12-1991)    180cm
#
#        National                                          Positions  \
# 0       England  Defender (Left), Midfielder (Centre, Left, Right)
# 1       Germany                Midfielder (Centre, Right), Forward
# 2       England        Defender (Centre), Defensive Midfielder (C)
# 3        Brazil                                         Goalkeeper
# 4         Ghana       Defender (Right), Midfielder (Centre, Right)
# 5        Brazil                                  Defender (Centre)
# 6        France                                  Defender (Centre)
# 7        Norway               Attacking Midfielder (Centre, Right)
# 8         Spain                       Midfielder (Centre), Forward
# 9        Brazil        Attacking Midfielder (Left, Right), Forward
# 10        Spain                                         Goalkeeper
# 11      Belgium          Midfielder (Centre, Left, Right), Forward
# 12  Netherlands                     Defender (Centre, Left, Right)
# 13        Italy                            Defender (Centre, Left)
# 14      England                       Attacking Midfielder (Right)
# 15       Brazil        Attacking Midfielder (Left, Right), Forward
# 16      England  Defender (Centre, Right), Defensive Midfielder...
# 17        Japan                     Defender (Centre, Left, Right)
# 18      England                                    Defender (Left)
# 19       Poland  Defender (Centre, Left), Defensive Midfielder (C)
# 20     Scotland         Defender (Centre, Left), Midfielder (Left)
# 21      England          Midfielder (Centre, Left, Right), Forward
# 22      Ukraine  Defender (Left), Midfielder (Centre, Left, Right)
# 23        Italy                           Defensive Midfielder (C)
#
#     Unnamed: 0         CLB       Main_position Height_y   Foot      Contract  \
# 0         19.0  Arsenal FC        Right Winger    1,78m   left  Jun 30, 2027
# 1         22.0  Arsenal FC      Centre-Forward    1,93m   left  Jun 30, 2028
# 2         14.0  Arsenal FC    Central Midfield    1,88m  right  Jun 30, 2028
# 3          1.0  Arsenal FC          Goalkeeper    1,90m  right  Jun 30, 2025
# 4         12.0  Arsenal FC  Defensive Midfield    1,85m  right  Jun 30, 2025
# 5          3.0  Arsenal FC         Centre-Back    1,90m   left  Jun 30, 2027
# 6          2.0  Arsenal FC         Centre-Back    1,92m  right  Jun 30, 2027
# 7         16.0  Arsenal FC  Attacking Midfield    1,78m   left  Jun 30, 2028
# 8         15.0  Arsenal FC    Central Midfield    1,89m   left  Jun 30, 2028
# 9         17.0  Arsenal FC         Left Winger    1,78m  right  Jun 30, 2027
# 10         0.0  Arsenal FC          Goalkeeper    1,83m  right  Jun 30, 2028
# 11        18.0  Arsenal FC         Left Winger    1,72m  right  Jun 30, 2026
# 12         NaN         NaN                 NaN      NaN    NaN           NaN
# 13         5.0  Arsenal FC           Left-Back    1,88m   left  Jun 30, 2029
# 14        20.0  Arsenal FC        Right Winger    1,76m   left  Jun 30, 2030
# 15        23.0  Arsenal FC      Centre-Forward    1,75m  right  Jun 30, 2027
# 16         9.0  Arsenal FC          Right-Back    1,86m  right  Jun 30, 2028
# 17        11.0  Arsenal FC          Right-Back    1,88m  right  Jun 30, 2026
# 18         6.0  Arsenal FC           Left-Back    1,78m   left             -
# 19         4.0  Arsenal FC         Centre-Back    1,89m   left  Jun 30, 2028
# 20         8.0  Arsenal FC           Left-Back    1,80m   left  Jun 30, 2025
# 21        21.0  Arsenal FC        Right Winger    1,70m  right  May 31, 2025
# 22         7.0  Arsenal FC           Left-Back    1,75m   left  Jun 30, 2026
# 23        13.0  Arsenal FC  Defensive Midfield    1,78m  right  Jun 30, 2025
#
#    Market_Value
# 0      €150.00m
# 1       €70.00m
# 2      €110.00m
# 3        €2.00m
# 4       €15.00m
# 5       €75.00m
# 6       €80.00m
# 7      €100.00m
# 8       €35.00m
# 9       €55.00m
# 10      €40.00m
# 11      €30.00m
# 12          NaN
# 13      €40.00m
# 14      €55.00m
# 15      €40.00m
# 16      €50.00m
# 17      €25.00m
# 18      €28.00m
# 19      €22.00m
# 20      €10.00m
# 21      €15.00m
# 22      €22.00m
# 23       €8.00m

# %%
n = base_info["Player"].unique ()
n.shape
# Out:
# (2655,)

# %% [markdown]
# ## Read *data_summer_EPL.csv*

# %%
info = []
for league in leagues:
    path = f"ds108/{league}/data_summary_{league}.csv"
    data_sum = pd.read_csv (path)
    info.append (data_sum)
    
data_summary = pd.concat (info, ignore_index=True)

data_summary.drop (columns=['Unnamed: 0'], inplace=True)
SpG = data_summary ["SpG"]
data_summary.drop ('SpG', axis=1, inplace=True)

SpG = pd.DataFrame (SpG)
print ("SpG shape:",SpG.shape)
data_summary
# Out:
# SpG shape: (2806, 1)
#               Player   Apps  Mins Goals Assists Yel Red   PS% AerialsWon MotM  \
# 0      Mohamed Salah     32  2840    27      18   1   -  74.3        0.3   10
# 1        Bukayo Saka  16(3)  1372     6      10   3   -  84.3        0.4    6
# 2     Alexander Isak     29  2351    21       6   1   -  75.2        0.9    5
# 3      Matheus Cunha  24(3)  2168    14       4   3   -  77.9        0.4    8
# 4     Erling Haaland     28  2484    21       3   2   -  66.4        1.8    6
# ...              ...    ...   ...   ...     ...  ..  ..   ...        ...  ...
# 2801  Bernard Nguene   0(1)    13     -       -   -   -   100          -    -
# 2802   Paul Akouokou   0(2)    19     -       -   1   -  66.7          -    -
# 2803      Bamo Meïté      6   413     -       -   2   1  88.6          1    -
# 2804    Élysée Logbo   0(1)    26     -       -   -   -    75          -    -
# 2805       Zabi Gueu   0(2)    18     -       -   -   1    75          -    -
#
#       Rating
# 0       7.75
# 1       7.59
# 2       7.44
# 3       7.37
# 4       7.37
# ...      ...
# 2801    5.87
# 2802    5.79
# 2803    5.76
# 2804    5.67
# 2805    5.46
#
# [2806 rows x 11 columns]

# %%
n = data_summary["Player"].unique ()
n.shape
# Out:
# (2655,)

# %% [markdown]
# ## *Football_Player_Profile*

# %%
# Football_Player_Profile = pd.merge (base_info, data_summary, on='Player')
Football_Player_Profile = pd.concat ([base_info, data_summary.drop (columns=['Player'])],axis=1)
Football_Player_Profile = Football_Player_Profile.rename (columns={'Yel':'YelC','Red':'RedC','AerialsWon':'ArlW'})

Football_Player_Profile
# Out:
#               Player             Club  League                        Age  \
# 0      Mohamed Salah        Liverpool     EPL  32 years old (15-06-1992)
# 1        Bukayo Saka          Arsenal     EPL  23 years old (05-09-2001)
# 2     Alexander Isak        Newcastle     EPL  25 years old (21-09-1999)
# 3      Matheus Cunha           Wolves     EPL  25 years old (27-05-1999)
# 4     Erling Haaland  Manchester City     EPL  24 years old (21-07-2000)
# ...              ...              ...     ...                        ...
# 2801  Bernard Nguene             Nice  Ligue1  18 years old (04-08-2006)
# 2802   Paul Akouokou             Lyon  Ligue1  27 years old (20-12-1997)
# 2803      Bamo Meïté      Montpellier  Ligue1  23 years old (03-12-2001)
# 2804    Élysée Logbo         Le Havre  Ligue1  20 years old (06-05-2004)
# 2805       Zabi Gueu            Reims  Ligue1  18 years old (24-09-2006)
#
#      Height     National                                          Positions  \
# 0     175cm        Egypt  Attacking Midfielder (Centre, Left, Right), Fo...
# 1     178cm      England  Defender (Left), Midfielder (Centre, Left, Right)
# 2     192cm       Sweden               Attacking Midfielder (Left), Forward
# 3     183cm       Brazil       Attacking Midfielder (Centre, Left), Forward
# 4     194cm       Norway                                            Forward
# ...     ...          ...                                                ...
# 2801  178cm     Cameroon                                            Forward
# 2802  181cm  Ivory Coast                           Defensive Midfielder (C)
# 2803  183cm          NaN                                  Defender (Centre)
# 2804  188cm       France                                            Forward
# 2805  191cm          NaN                                         Midfielder
#
#        Apps  Mins Goals Assists YelC RedC   PS% ArlW MotM  Rating
# 0        32  2840    27      18    1    -  74.3  0.3   10    7.75
# 1     16(3)  1372     6      10    3    -  84.3  0.4    6    7.59
# 2        29  2351    21       6    1    -  75.2  0.9    5    7.44
# 3     24(3)  2168    14       4    3    -  77.9  0.4    8    7.37
# 4        28  2484    21       3    2    -  66.4  1.8    6    7.37
# ...     ...   ...   ...     ...  ...  ...   ...  ...  ...     ...
# 2801   0(1)    13     -       -    -    -   100    -    -    5.87
# 2802   0(2)    19     -       -    1    -  66.7    -    -    5.79
# 2803      6   413     -       -    2    1  88.6    1    -    5.76
# 2804   0(1)    26     -       -    -    -    75    -    -    5.67
# 2805   0(2)    18     -       -    -    1    75    -    -    5.46
#
# [2806 rows x 17 columns]

# %%
Football_Player_Profile.shape
# Out:
# (2806, 17)

# %% [markdown]
# # Create `Offensive_Profile` Dataset

# %% [markdown]
# ## Read *data_details_Goals_EPL.csv*
# > Goals

# %%
# Các cách đổi thứ tự cột
'''
Cách 1: df = df[['C','A','B']]
Cách 2: Sử dụng reindex () theo axis=1
    df = df.reindex (columns=['C','A','B'])
Cách 3: col = df.pop ('C')
        df.insert (0, 'C', col) --> Xoá rồi chèn
'''
# Out:
# "\nCách 1: df = df[['C','A','B']]\nCách 2: Sử dụng reindex () theo axis=1\n    df = df.reindex (columns=['C','A','B'])\nCách 3: col = df.pop ('C')\n        df.insert (0, 'C', col) --> Xoá rồi chèn\n"

# %%
info = []
for league in leagues:
    Goal = pd.read_csv (f'ds108/{league}/data_details_Goals_{league}.csv')
    Goal = Goal.reindex (columns =[
                                'Total','OutOfBox',
                                'SixYardBox','PenaltyArea'
                            ])
    Goal = Goal.rename (columns = {
                        'Total':'TotGs',
                        'OutOfBox':'OOGBs',
                        'SixYardBox':'SYBGs',
                        'PenaltyArea':'PAGs'
                    })
    info.append (Goal)
    
Goals = pd.concat (info).reset_index (drop=True)
SpG = SpG.reset_index (drop=True)
# Gộp thuộc tính SpG 
Goals = pd.concat ([SpG,Goals], axis=1)

print ("Goals Dataset's Shape:",Goals.shape)
Goals
# Out:
# Goals Dataset's Shape: (2806, 5)
#       SpG TotGs OOGBs SYBGs PAGs
# 0     3.4   0.8     -   0.2  0.7
# 1     2.7   0.3     -   0.1  0.3
# 2     2.9   0.7   0.1   0.3  0.3
# 3     3.3   0.5   0.2     -  0.3
# 4     3.6   0.8   0.1   0.1  0.5
# ...   ...   ...   ...   ...  ...
# 2801    -     -     -     -    -
# 2802    -     -     -     -    -
# 2803  0.2     -     -     -    -
# 2804    1     -     -     -    -
# 2805    -     -     -     -    -
#
# [2806 rows x 5 columns]

# %% [markdown]
# ## Read *data_details_Shots_--.csv*
# > Shots

# %%
info = []
for league in leagues:
    Shot = pd.read_csv (f'ds108/{league}/data_details_Shots_{league}.csv') 
    Shot = Shot.rename (columns = {
        'Total' : 'TotSh',
        'OutOfBox' : 'OOBSh',
        'SixYardBox' : 'SYBSh',
        'PenaltyArea' : 'PASh'
    })
    info.append (Shot)
Shots = pd.concat (info, ignore_index=True)
Shots
# Out:
#      TotSh OOBSh SYBSh PASh
# 0      3.4   0.3   0.4  2.7
# 1      2.7   0.6   0.2  1.9
# 2      2.9   0.5   0.3    2
# 3      3.3   1.6   0.1  1.6
# 4      3.6   0.3   0.7  2.6
# ...    ...   ...   ...  ...
# 2801     -     -     -    -
# 2802     -     -     -    -
# 2803   0.2   0.2     -    -
# 2804     1     -     -    1
# 2805     -     -     -    -
#
# [2806 rows x 4 columns]

# %% [markdown]
# ## Read *data_details_Dribbles_--.csv*
# > Dribbles

# %%
info = []
for league in leagues:
    Dribble = pd.read_csv (f'ds108/{league}/data_details_Dribbles_{league}.csv') 
    Dribble = Dribble [['Total Dribbles','Unsuccessful','Successful']]
    Dribble.rename (columns={
        'Total Dribbles' : 'TotDrib',
        'Unsuccessful' : 'UnDrib',
        'Successful' : 'SucDrib'
    }, inplace=True)
    info.append (Dribble)
Dribbles = pd.concat (info).reset_index (drop=True)
Dribbles
# Out:
#      TotDrib UnDrib SucDrib
# 0        3.7      2     1.6
# 1        4.3    2.4     1.9
# 2        2.9    1.4     1.4
# 3        4.4    2.5     1.9
# 4        1.1    0.8     0.4
# ...      ...    ...     ...
# 2801       1      1       -
# 2802       -      -       -
# 2803     0.2      -     0.2
# 2804       -      -       -
# 2805       -      -       -
#
# [2806 rows x 3 columns]

# %% [markdown]
# ## Read *data_details_Possession loss_--.csv*
# > Possession_Loss

# %%
info = []
for league in leagues:
    possloss = pd.read_csv (f"ds108/{league}/data_details_Possession loss_{league}.csv")
    possloss.rename (columns = {
            'UnsuccessfulTouches' : "UnTch",
            'Dispossessed' : 'Dispo'
        }, inplace=True)
    info.append (possloss)
    
Possession_Loss = pd.concat (info).reset_index (drop=True)
Possession_Loss
# Out:
#      UnTch Dispo
# 0      3.1   1.8
# 1      1.4   1.9
# 2        2   1.7
# 3      2.5   1.6
# 4      1.4   0.9
# ...    ...   ...
# 2801     1     -
# 2802   0.5     -
# 2803   0.5   0.5
# 2804     -     3
# 2805     -     -
#
# [2806 rows x 2 columns]

# %% [markdown]
# ## Read *data_details_Aerial_--.csv*
# > Aerial

# %%
info = []
for league in leagues:
    Aeri = pd.read_csv (f'ds108/{league}/data_details_Aerial_{league}.csv') 
    Aeri.rename (columns={
        'Total' : 'TotAD',
        'Won' : 'WonAD',
        'Lost' : 'LostAD'
    }, inplace=True)
    print (f"{league}: {Aeri.shape}")
    info.append (Aeri)
Aerial = pd.concat (info, ignore_index=True)
Aerial
# Out:
# EPL: (564, 3)
# Laliga: (587, 3)
# Bundesliga: (487, 3)
# SerieA: (625, 3)
# Ligue1: (543, 3)
#      TotAD WonAD LostAD
# 0      0.7   0.3    0.4
# 1      1.4   0.4    0.9
# 2      2.5   0.9    1.6
# 3      1.2   0.4    0.9
# 4      3.4   1.8    1.6
# ...    ...   ...    ...
# 2801     2     -      2
# 2802     -     -      -
# 2803   2.2     1    1.2
# 2804     2     -      2
# 2805     -     -      -
#
# [2806 rows x 3 columns]

# %% [markdown]
# ## Create *Offensive_Profile* DataSet

# %%
Offensive_Profile = pd.concat ([Goals, Shots, Dribbles, Possession_Loss, Aerial], axis=1)
Offensive_Profile
# Out:
#       SpG TotGs OOGBs SYBGs PAGs TotSh OOBSh SYBSh PASh TotDrib UnDrib  \
# 0     3.4   0.8     -   0.2  0.7   3.4   0.3   0.4  2.7     3.7      2
# 1     2.7   0.3     -   0.1  0.3   2.7   0.6   0.2  1.9     4.3    2.4
# 2     2.9   0.7   0.1   0.3  0.3   2.9   0.5   0.3    2     2.9    1.4
# 3     3.3   0.5   0.2     -  0.3   3.3   1.6   0.1  1.6     4.4    2.5
# 4     3.6   0.8   0.1   0.1  0.5   3.6   0.3   0.7  2.6     1.1    0.8
# ...   ...   ...   ...   ...  ...   ...   ...   ...  ...     ...    ...
# 2801    -     -     -     -    -     -     -     -    -       1      1
# 2802    -     -     -     -    -     -     -     -    -       -      -
# 2803  0.2     -     -     -    -   0.2   0.2     -    -     0.2      -
# 2804    1     -     -     -    -     1     -     -    1       -      -
# 2805    -     -     -     -    -     -     -     -    -       -      -
#
#      SucDrib UnTch Dispo TotAD WonAD LostAD
# 0        1.6   3.1   1.8   0.7   0.3    0.4
# 1        1.9   1.4   1.9   1.4   0.4    0.9
# 2        1.4     2   1.7   2.5   0.9    1.6
# 3        1.9   2.5   1.6   1.2   0.4    0.9
# 4        0.4   1.4   0.9   3.4   1.8    1.6
# ...      ...   ...   ...   ...   ...    ...
# 2801       -     1     -     2     -      2
# 2802       -   0.5     -     -     -      -
# 2803     0.2   0.5   0.5   2.2     1    1.2
# 2804       -     -     3     2     -      2
# 2805       -     -     -     -     -      -
#
# [2806 rows x 17 columns]

# %% [markdown]
# # Create `Defensive_Profile` Dataset

# %%
info = []
for league in leagues:
    tackle = pd.read_csv (f'ds108/{league}/data_details_Tackles_{league}.csv')
    interception = pd.read_csv (f'ds108/{league}/data_details_Interception_{league}.csv')
    foul = pd.read_csv (f'ds108/{league}/data_details_Fouls_{league}.csv')
    offside = pd.read_csv (f'ds108/{league}/data_details_Offsides_{league}.csv')
    clearance = pd.read_csv (f'ds108/{league}/data_details_Clearances_{league}.csv')
    blocked = pd.read_csv (f'ds108/{league}/data_details_Blocks_{league}.csv')
    save = pd.read_csv (f'ds108/{league}/data_details_Saves_{league}.csv')
    save = save.reindex (columns=[
        'Total','SixYardBox',
        'PenaltyArea','OutOfBox'
    ])
    offensive = pd.concat ([tackle, interception, foul, offside, clearance,
                           blocked, save],axis=1) 
    offensive.columns = [
                            'TotTkl', 'DribPast','AttTkl','Intercpt',
                            'Fouled','Fouls','COF','Clr','BlkSh','BlkCr',
                            'BlkPs','TotSav', 'OOBSav', 'SYBSav','PASav'
                        ]
    print (f"{league}: {offensive.shape}")
    info.append (offensive)
offensive
Defensive_Profile = pd.concat (info, ignore_index=True)
Defensive_Profile
# Out:
# EPL: (564, 15)
# Laliga: (587, 15)
# Bundesliga: (487, 15)
# SerieA: (625, 15)
# Ligue1: (543, 15)
#      TotTkl DribPast AttTkl Intercpt Fouled Fouls  COF  Clr BlkSh BlkCr BlkPs  \
# 0       0.6      0.2    0.8      0.2      1   0.7  0.5  0.2     -     -   0.3
# 1       1.2      0.5    1.7      0.1    1.8   0.7  0.2  0.3     -   0.1   0.9
# 2       0.4      0.2    0.7      0.1    0.4   0.8  0.7  0.5   0.1     -   0.5
# 3       1.2      0.9    2.1      0.6    2.2   1.4  0.3  0.7     -   0.1   0.6
# 4       0.3      0.1    0.5      0.2    0.4   0.8  0.1  0.8     -     -   0.4
# ...     ...      ...    ...      ...    ...   ...  ...  ...   ...   ...   ...
# 2801      -        -      -        -      -     1    -    -     -     -     -
# 2802    0.5        -    0.5      0.5      -   1.5    -    -     -     -     -
# 2803    0.7      0.2    0.8      0.5    0.7   1.2    -  2.2   0.5     -     -
# 2804      -        -      -        -      -     -    -    -     -     -     -
# 2805      -        -      -        -      -   0.5    -  0.5     -     -     -
#
#      TotSav OOBSav SYBSav PASav
# 0         -      -      -     -
# 1         -      -      -     -
# 2         -      -      -     -
# 3         -      -      -     -
# 4         -      -      -     -
# ...     ...    ...    ...   ...
# 2801      -      -      -     -
# 2802      -      -      -     -
# 2803      -      -      -     -
# 2804      -      -      -     -
# 2805      -      -      -     -
#
# [2806 rows x 15 columns]

# %% [markdown]
# # Create `Passing_Profile` Dataset

# %%
info = []
for league in leagues:
    passes = pd.read_csv (f'ds108/{league}/data_details_Passes_{league}.csv')
    key_pass = pd.read_csv (f'ds108/{league}/data_details_Key passes_{league}.csv')
    assists = pd.read_csv (f'ds108/{league}/data_details_Assists_{league}.csv')
    assists = assists.reindex (columns=[
        'Total','Cross', 'Corner','Throughball',
        'Freekick','Throwin','Other'
    ])
    df = pd.concat ([passes, key_pass, assists],axis=1) 
    df.columns = [
                    'TotPs', 'AccLB','InAccLB','AccSP',
                    'InAccSP','TotKPs','LKPs','SKPs',
                    'TotAss', 'CrAss','CorAss','ThrbAss',
                    'FreAss','ThrInAss','OthAss'
                ]
    print (f"{league}: {df.shape}")
    info.append (df)
Passing_Profile = pd.concat (info, ignore_index=True)
Passing_Profile
# Out:
# EPL: (564, 15)
# Laliga: (587, 15)
# Bundesliga: (487, 15)
# SerieA: (625, 15)
# Ligue1: (543, 15)
#      TotPs AccLB InAccLB AccSP InAccSP TotKPs LKPs SKPs TotAss CrAss CorAss  \
# 0       31   0.7     0.7  22.3     7.3    2.3  0.2  2.2    0.6   0.1      -
# 1     24.1   0.3     0.5  20.1     3.3    2.3  0.6  1.7    0.5   0.3    0.2
# 2     19.2   0.4     0.4    14     4.4    1.3  0.1  1.2    0.2     -      -
# 3     28.8   1.4     1.2    21     5.1    1.7  0.2  1.5    0.1     -      -
# 4       12   0.1       -   7.9       4    0.9    -  0.9    0.1     -      -
# ...    ...   ...     ...   ...     ...    ...  ...  ...    ...   ...    ...
# 2801     2     -       -     2       -      -    -    -      -     -      -
# 2802   7.5   0.5       -   4.5     2.5      -    -    -      -     -      -
# 2803  26.3   0.5     0.5  22.8     2.5      -    -    -      -     -      -
# 2804     4     -       -     3       1      -    -    -      -     -      -
# 2805     6     -     0.5   4.5       1      -    -    -      -     -      -
#
#      ThrbAss FreAss ThrInAss OthAss
# 0          -      -        -    0.5
# 1        0.1      -        -    0.2
# 2          -      -        -    0.2
# 3          -      -        -    0.1
# 4          -      -        -    0.1
# ...      ...    ...      ...    ...
# 2801       -      -        -      -
# 2802       -      -        -      -
# 2803       -      -        -      -
# 2804       -      -        -      -
# 2805       -      -        -      -
#
# [2806 rows x 15 columns]

# %% [markdown]
# # Create `Football_Player_Full` Dataset

# %%
Football_Player_Full = pd.concat ([Football_Player_Profile,Offensive_Profile,Defensive_Profile,Passing_Profile],axis=1)
# Football_Player_Full = Football_Player_Full.sort_values (by=['League','Club']).reset_index(drop=True)
Football_Player_Full
# Out:
#               Player             Club  League                        Age  \
# 0      Mohamed Salah        Liverpool     EPL  32 years old (15-06-1992)
# 1        Bukayo Saka          Arsenal     EPL  23 years old (05-09-2001)
# 2     Alexander Isak        Newcastle     EPL  25 years old (21-09-1999)
# 3      Matheus Cunha           Wolves     EPL  25 years old (27-05-1999)
# 4     Erling Haaland  Manchester City     EPL  24 years old (21-07-2000)
# ...              ...              ...     ...                        ...
# 2801  Bernard Nguene             Nice  Ligue1  18 years old (04-08-2006)
# 2802   Paul Akouokou             Lyon  Ligue1  27 years old (20-12-1997)
# 2803      Bamo Meïté      Montpellier  Ligue1  23 years old (03-12-2001)
# 2804    Élysée Logbo         Le Havre  Ligue1  20 years old (06-05-2004)
# 2805       Zabi Gueu            Reims  Ligue1  18 years old (24-09-2006)
#
#      Height     National                                          Positions  \
# 0     175cm        Egypt  Attacking Midfielder (Centre, Left, Right), Fo...
# 1     178cm      England  Defender (Left), Midfielder (Centre, Left, Right)
# 2     192cm       Sweden               Attacking Midfielder (Left), Forward
# 3     183cm       Brazil       Attacking Midfielder (Centre, Left), Forward
# 4     194cm       Norway                                            Forward
# ...     ...          ...                                                ...
# 2801  178cm     Cameroon                                            Forward
# 2802  181cm  Ivory Coast                           Defensive Midfielder (C)
# 2803  183cm          NaN                                  Defender (Centre)
# 2804  188cm       France                                            Forward
# 2805  191cm          NaN                                         Midfielder
#
#        Apps  Mins Goals Assists YelC RedC   PS% ArlW MotM  Rating  SpG TotGs  \
# 0        32  2840    27      18    1    -  74.3  0.3   10    7.75  3.4   0.8
# 1     16(3)  1372     6      10    3    -  84.3  0.4    6    7.59  2.7   0.3
# 2        29  2351    21       6    1    -  75.2  0.9    5    7.44  2.9   0.7
# 3     24(3)  2168    14       4    3    -  77.9  0.4    8    7.37  3.3   0.5
# 4        28  2484    21       3    2    -  66.4  1.8    6    7.37  3.6   0.8
# ...     ...   ...   ...     ...  ...  ...   ...  ...  ...     ...  ...   ...
# 2801   0(1)    13     -       -    -    -   100    -    -    5.87    -     -
# 2802   0(2)    19     -       -    1    -  66.7    -    -    5.79    -     -
# 2803      6   413     -       -    2    1  88.6    1    -    5.76  0.2     -
# 2804   0(1)    26     -       -    -    -    75    -    -    5.67    1     -
# 2805   0(2)    18     -       -    -    1    75    -    -    5.46    -     -
#
#      OOGBs SYBGs PAGs TotSh OOBSh SYBSh  ... Fouls  COF  Clr BlkSh BlkCr  \
# 0        -   0.2  0.7   3.4   0.3   0.4  ...   0.7  0.5  0.2     -     -
# 1        -   0.1  0.3   2.7   0.6   0.2  ...   0.7  0.2  0.3     -   0.1
# 2      0.1   0.3  0.3   2.9   0.5   0.3  ...   0.8  0.7  0.5   0.1     -
# 3      0.2     -  0.3   3.3   1.6   0.1  ...   1.4  0.3  0.7     -   0.1
# 4      0.1   0.1  0.5   3.6   0.3   0.7  ...   0.8  0.1  0.8     -     -
# ...    ...   ...  ...   ...   ...   ...  ...   ...  ...  ...   ...   ...
# 2801     -     -    -     -     -     -  ...     1    -    -     -     -
# 2802     -     -    -     -     -     -  ...   1.5    -    -     -     -
# 2803     -     -    -   0.2   0.2     -  ...   1.2    -  2.2   0.5     -
# 2804     -     -    -     1     -     -  ...     -    -    -     -     -
# 2805     -     -    -     -     -     -  ...   0.5    -  0.5     -     -
#
#      BlkPs TotSav OOBSav SYBSav PASav TotPs AccLB InAccLB AccSP InAccSP  \
# 0      0.3      -      -      -     -    31   0.7     0.7  22.3     7.3
# 1      0.9      -      -      -     -  24.1   0.3     0.5  20.1     3.3
# 2      0.5      -      -      -     -  19.2   0.4     0.4    14     4.4
# 3      0.6      -      -      -     -  28.8   1.4     1.2    21     5.1
# 4      0.4      -      -      -     -    12   0.1       -   7.9       4
# ...    ...    ...    ...    ...   ...   ...   ...     ...   ...     ...
# 2801     -      -      -      -     -     2     -       -     2       -
# 2802     -      -      -      -     -   7.5   0.5       -   4.5     2.5
# 2803     -      -      -      -     -  26.3   0.5     0.5  22.8     2.5
# 2804     -      -      -      -     -     4     -       -     3       1
# 2805     -      -      -      -     -     6     -     0.5   4.5       1
#
#      TotKPs LKPs SKPs TotAss CrAss CorAss ThrbAss FreAss ThrInAss OthAss
# 0       2.3  0.2  2.2    0.6   0.1      -       -      -        -    0.5
# 1       2.3  0.6  1.7    0.5   0.3    0.2     0.1      -        -    0.2
# 2       1.3  0.1  1.2    0.2     -      -       -      -        -    0.2
# 3       1.7  0.2  1.5    0.1     -      -       -      -        -    0.1
# 4       0.9    -  0.9    0.1     -      -       -      -        -    0.1
# ...     ...  ...  ...    ...   ...    ...     ...    ...      ...    ...
# 2801      -    -    -      -     -      -       -      -        -      -
# 2802      -    -    -      -     -      -       -      -        -      -
# 2803      -    -    -      -     -      -       -      -        -      -
# 2804      -    -    -      -     -      -       -      -        -      -
# 2805      -    -    -      -     -      -       -      -        -      -
#
# [2806 rows x 64 columns]

# %% [markdown]
# # Create CSV Files From Datasets

# %% [markdown]
# *Warnings: Don't run!*

# %%
Football_Player_Profile.to_csv ('Football_Player_Profile.csv')
Offensive_Profile.to_csv ('Offensive_Profile.csv')
Defensive_Profile.to_csv ('Defensive_Profensive.csv')
Passing_Profile.to_csv ('Passing_Profile.csv')
Football_Player_Full.to_csv ('Football_Player_Full_Dataset.csv')
